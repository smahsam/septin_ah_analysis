# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import seaborn as sns
import pandas as pd
import os
import MDAnalysis as mda
from MDAnalysis.coordinates.GRO import GROWriter
from scipy.spatial import Voronoi

def compute_apl_voronoi(xyz_positions, plot=False):
    """
    Compute area-per-lipid (APL) using Voronoi tessellation.
    
    Parameters:
        xyz_positions (np.ndarray): shape (N, 3) array of positions
        plot (bool): whether to plot the Voronoi diagram
    Returns:
        apl_values (np.ndarray): APL for each point (in same order as input)
    """

    # Project to XY plane
    points_2d = xyz_positions[:, :2]

    # Voronoi tessellation
    vor = Voronoi(points_2d)

    # Compute areas
    apl_values = np.zeros(len(points_2d))

    for i, region_index in enumerate(vor.point_region):
        vertices = vor.regions[region_index]
        
        if -1 in vertices or len(vertices) == 0:
            apl_values[i] = np.nan  # Infinite region (at the edge), set NaN
            continue

        polygon = vor.vertices[vertices]
        x = polygon[:, 0]
        y = polygon[:, 1]
        
        # Area of polygon
        area = 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))
        apl_values[i] = area

    if plot:
        fig, ax = plt.subplots(figsize=(6, 6))
        ax.plot(points_2d[:, 0], points_2d[:, 1], 'o')
        for region in vor.regions:
            if not region or -1 in region:
                continue
            polygon = [vor.vertices[i] for i in region]
            plt.fill(*zip(*polygon), alpha=0.4)
        plt.title('Voronoi diagram')
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.show()

    return apl_values


def replicate_xy(gro_filename, n_replicas=1):
    """
    Replicate GRO positions in XY plane by periodic box shifts.
    
    Parameters:
        gro_filename (str): path to .gro file
        n_replicas (int): number of neighbors in each direction (default 1 → 1 box shift each way)
    
    Returns:
        replicated_positions (np.ndarray): array of replicated positions (N * replicas, 3)
        box (np.ndarray): box dimensions
    """

    # Load the GRO file
    u = mda.Universe(gro_filename)
    atoms = u.select_atoms('name P')
    positions = atoms.positions.copy()  # positions in Angstroms
    positions *= 0.1  # convert to nm (GROMACS uses nm)

    # Get box dimensions (in nm)
    box = u.dimensions[:3]  # [lx, ly, lz]
    box_x, box_y = box[0], box[1]

    # List to collect all images
    replicated_positions = []

    # Define shifts in XY
    shifts = []
    for i in range(-n_replicas, n_replicas+1):
        for j in range(-n_replicas, n_replicas+1):
            shifts.append((i * box_x, j * box_y))
    
    # Replicate
    for dx, dy in shifts:
        shifted = positions.copy()
        shifted[:, 0] += dx
        shifted[:, 1] += dy
        replicated_positions.append(shifted)

    # Stack all images
    replicated_positions = np.vstack(replicated_positions)

    return replicated_positions, box



def kde_contour_plot(x, y, scatter_data,
                     xlim=None, ylim=None,
                     vmin=None, vmax=None,
                     xlabel="X", ylabel="Y", title="KDE Contour Plot",
                     fill=True, cmap="viridis",
                     png_filename=None,
                     bw_adjust=1.0,
                     add_colorbar=True):
    """
    KDE-based contour plot from x, y data with control over x/y limits and colorbar scaling.
    """
    plt.figure(figsize=(6, 5))
    
    # Plot KDE and capture the returned QuadContourSet
    kde = sns.kdeplot(
        x=x,
        y=y,
        fill=fill,
        cmap=cmap,
        levels=100,   # More smoothness
        thresh=0,     # Show everything
        bw_adjust=bw_adjust
    )

    # Manually set clim (colorbar limits) if requested
    if vmin is not None or vmax is not None:
        # kde.collections is a list of PolyCollections
        for collection in kde.collections:
            collection.set_clim(vmin=vmin, vmax=vmax)

    if add_colorbar:
        mappable = kde.collections[0]
        plt.colorbar(mappable, label="Density")

    if xlim:
        plt.xlim(xlim)
    if ylim:
        plt.ylim(ylim)

    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.scatter(scatter_data[:,0], scatter_data[:,1], c='red', s=10, alpha=0.5)
    plt.tight_layout()

    if png_filename:
        plt.savefig(png_filename)
        plt.close()
    else:
        plt.show()


def plot_membrane_property_fromCSV(csv_filename, gro_filename, png_filename, protein):
    # Get box vectors from the last non-empty line of the .gro file
    with open(gro_filename) as fp:
        last_line = ""
        for line in fp:
            stripped = line.strip()
            if stripped:
                last_line = stripped
    #box_x, box_y = [float(val) for val in last_line.split()[:2]]
    box_x = 11.0
    box_y = 11.0
    # Read data from CSV
    x_values = []
    y_values = []
    property_values = []
    membrane_property = "Membrane Property"
    with open(csv_filename) as fp:
        for lino, line in enumerate(fp):
            if lino == 0:
                membrane_property = line.split(",")[-1].strip()
                continue
            stripped = line.strip()
            if stripped:
                parts = stripped.split(",")
                if len(parts) >= 6:
                    if parts[1] == 'upper leaflet':
                        x, y, value = float(parts[2]), float(parts[3]), float(parts[5])
                        x_values.append(x)
                        y_values.append(y)
                        property_values.append(value)
    
    kde_contour_plot(x_values, y_values, protein, xlim=(0, 11.0), ylim=(0, 11.0), vmin=0.3, vmax=1.5, fill=True, cmap="viridis_r", bw_adjust=0.5,  title="APL", png_filename=png_filename)
    #plt.scatter(protein[:,0], protein[:,1], c='blue', s=4, alpha=0.5)


def plot_membrane_property_from_csv(csv_filename, gro_filename, png_filename, protein, resolution=50j):
    # Get box vectors from the last non-empty line of the .gro file
    with open(gro_filename) as fp:
        last_line = ""
        for line in fp:
            stripped = line.strip()
            if stripped:
                last_line = stripped
    #box_x, box_y = [float(val) for val in last_line.split()[:2]]
    box_x = 11.0
    box_y = 11.0
    # Read data from CSV
    x_values = []
    y_values = []
    property_values = []
    membrane_property = "Membrane Property"
    with open(csv_filename) as fp:
        for lino, line in enumerate(fp):
            if lino == 0:
                membrane_property = line.split(",")[-1].strip()
                continue
            stripped = line.strip()
            if stripped:
                parts = stripped.split(",")
                if len(parts) >= 6:
                    if parts[1] == 'upper leaflet':
                        x, y, value = float(parts[2]), float(parts[3]), float(parts[5])
                        x_values.append(x)
                        y_values.append(y)
                        property_values.append(value)

    # Build grid for contour plot
    grid_x, grid_y = np.mgrid[0:box_x:resolution, 0:box_y:resolution]
    points = np.stack((x_values, y_values), axis=-1)
    values = np.array(property_values)
    grid = griddata(points, values, (grid_x, grid_y), method='cubic')

    # Plot
    plt.figure(figsize=(6, 5))
    contour = plt.contourf(grid_x, grid_y, grid, cmap="viridis")
    cbar = plt.colorbar(contour)
    cbar.set_label(membrane_property)
    plt.scatter(protein[:,0], protein[:,1], c='red', s=4, alpha=0.5)
    plt.title(membrane_property)
    plt.xlabel("Box X (nm)")
    plt.ylabel("Box Y (nm)")
    plt.tight_layout()
    plt.savefig(png_filename, dpi=300)
    plt.close()
    return grid

def return_grid(csv_filename, gro_filename, resolution=50j):
    # Get box vectors from the last non-empty line of the .gro file
    with open(gro_filename) as fp:
        last_line = ""
        for line in fp:
            stripped = line.strip()
            if stripped:
                last_line = stripped
    #box_x, box_y = [float(val) for val in last_line.split()[:2]]
    box_x = 11.0
    box_y = 11.0
    # Read data from CSV
    x_values = []
    y_values = []
    property_values = []
    membrane_property = "Membrane Property"
    with open(csv_filename) as fp:
        for lino, line in enumerate(fp):
            if lino == 0:
                membrane_property = line.split(",")[-1].strip()
                continue
            stripped = line.strip()
            if stripped:
                parts = stripped.split(",")
                if len(parts) >= 6:
                    if parts[1] == 'upper leaflet':
                        x, y, value = float(parts[2]), float(parts[3]), float(parts[5])
                        x_values.append(x)
                        y_values.append(y)
                        property_values.append(value)

    # Build grid for contour plot
    grid_x, grid_y = np.mgrid[0:box_x:resolution, 0:box_y:resolution]
    points = np.stack((x_values, y_values), axis=-1)
    values = np.array(property_values)
    grid = griddata(points, values, (grid_x, grid_y), method='cubic') 
    return grid

# %%
u = mda.Universe('/mnt/ceph/users/mmofidi/gromacs/reduced/multiple/N2/traj_continuous_v1_400_reduced.pdb', '/mnt/ceph/users/mmofidi/gromacs/reduced/multiple/N2/traj_continuous_v1_400_reduced.xtc')
GRID = []
for ts in u.trajectory[-1000::10]:
    u.atoms.write('conf.gro')
    PROT = u.select_atoms("protein and name CA").positions[:,:2]
    os.system('fatslim apl -c conf.gro -n index.ndx --export-apl-raw bilayer_prot_apl.csv')
    plot_membrane_property_fromCSV(csv_filename="bilayer_prot_apl_frame_00000.csv", gro_filename="conf.gro", png_filename="./NX/" + str(ts.frame) + ".svg", protein=PROT/10.0)
    os.system('rm -rf *.old')
# Out:
# /mnt/home/asahoo/venv/lib/python3.8/site-packages/MDAnalysis/coordinates/XDR.py:203: UserWarning: Cannot write lock/offset file in same location as {self.filename}. Using slow offset calculation.
#   warnings.warn(f"Cannot write lock/offset file in same location as "
# /mnt/home/asahoo/venv/lib/python3.8/site-packages/MDAnalysis/coordinates/XDR.py:259: UserWarning: Couldn't save offsets because: [Errno 13] Permission denied: '/mnt/ceph/users/mmofidi/gromacs/reduced/multiple/N2/.traj_continuous_v1_400_reduced.xtc_offsets.npz'
#   warnings.warn("Couldn't save offsets because: {}".format(e))
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.694±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.724±0.000nm^2
# Area: Membrane=117.932±0.000nm^2 - Lower leaflet=117.161±0.000nm^2 - Upper leaflet=118.702±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.398 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=115.869±0.000nm^2 - Lower leaflet=115.596±0.000nm^2 - Upper leaflet=116.142±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 81.330 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.718±0.000nm^2
# Area: Membrane=117.585±0.000nm^2 - Lower leaflet=117.418±0.000nm^2 - Upper leaflet=117.753±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.302 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=116.624±0.000nm^2 - Lower leaflet=116.264±0.000nm^2 - Upper leaflet=116.985±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.749 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.684±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.709±0.000nm^2
# Area: Membrane=116.223±0.000nm^2 - Lower leaflet=116.093±0.000nm^2 - Upper leaflet=116.352±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.704 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.688±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=117.029±0.000nm^2 - Lower leaflet=117.107±0.000nm^2 - Upper leaflet=116.951±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.070 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.183±0.000nm^2 - Lower leaflet=114.667±0.000nm^2 - Upper leaflet=115.698±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.757 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.587±0.000nm^2 - Lower leaflet=115.713±0.000nm^2 - Upper leaflet=115.460±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 81.429 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 35 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.949±0.000nm^2 - Lower leaflet=116.224±0.000nm^2 - Upper leaflet=115.674±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 100.354 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 42 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.674±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.696±0.000nm^2
# Area: Membrane=114.580±0.000nm^2 - Lower leaflet=114.941±0.000nm^2 - Upper leaflet=114.219±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 100.011 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.510±0.000nm^2 - Lower leaflet=116.516±0.000nm^2 - Upper leaflet=116.504±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.532 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=117.108±0.000nm^2 - Lower leaflet=117.167±0.000nm^2 - Upper leaflet=117.049±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.384 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.672±0.000nm^2 - Upper leaflet=0.730±0.000nm^2
# Area: Membrane=119.016±0.000nm^2 - Lower leaflet=118.272±0.000nm^2 - Upper leaflet=119.761±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.284 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=115.778±0.000nm^2 - Lower leaflet=115.408±0.000nm^2 - Upper leaflet=116.148±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.662 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 83 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.674±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.698±0.000nm^2
# Area: Membrane=114.592±0.000nm^2 - Lower leaflet=114.658±0.000nm^2 - Upper leaflet=114.525±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 181.069 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.702±0.000nm^2
# Area: Membrane=115.427±0.000nm^2 - Lower leaflet=115.739±0.000nm^2 - Upper leaflet=115.115±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.076 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=115.981±0.000nm^2 - Lower leaflet=115.898±0.000nm^2 - Upper leaflet=116.064±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.673 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 32 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.673±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.696±0.000nm^2
# Area: Membrane=114.457±0.000nm^2 - Lower leaflet=114.729±0.000nm^2 - Upper leaflet=114.184±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 105.848 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.677±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.702±0.000nm^2
# Area: Membrane=115.158±0.000nm^2 - Lower leaflet=115.204±0.000nm^2 - Upper leaflet=115.112±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.290 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.933±0.000nm^2 - Lower leaflet=116.137±0.000nm^2 - Upper leaflet=115.729±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 110.446 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.698±0.000nm^2
# Area: Membrane=114.705±0.000nm^2 - Lower leaflet=114.931±0.000nm^2 - Upper leaflet=114.479±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.563 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 51 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.707±0.000nm^2 - Lower leaflet=115.887±0.000nm^2 - Upper leaflet=115.527±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 116.618 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.785±0.000nm^2 - Lower leaflet=117.043±0.000nm^2 - Upper leaflet=116.526±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.657 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.671±0.000nm^2 - Lower leaflet=0.649±0.000nm^2 - Upper leaflet=0.695±0.000nm^2
# Area: Membrane=114.088±0.000nm^2 - Lower leaflet=114.195±0.000nm^2 - Upper leaflet=113.982±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 83.424 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=115.463±0.000nm^2 - Lower leaflet=115.599±0.000nm^2 - Upper leaflet=115.327±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.978 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.688±0.000nm^2 - Lower leaflet=0.664±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=116.907±0.000nm^2 - Lower leaflet=116.789±0.000nm^2 - Upper leaflet=117.026±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 117.350 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 50 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.722±0.000nm^2
# Area: Membrane=117.345±0.000nm^2 - Lower leaflet=116.200±0.000nm^2 - Upper leaflet=118.489±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 133.197 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=115.513±0.000nm^2 - Lower leaflet=115.084±0.000nm^2 - Upper leaflet=115.942±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.446 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=115.505±0.000nm^2 - Lower leaflet=114.328±0.000nm^2 - Upper leaflet=116.681±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 117.038 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 97 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.677±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.059±0.000nm^2 - Lower leaflet=114.692±0.000nm^2 - Upper leaflet=115.427±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 165.268 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.646±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=115.445±0.000nm^2 - Lower leaflet=113.713±0.000nm^2 - Upper leaflet=117.177±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 95.537 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 69 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.719±0.000nm^2
# Area: Membrane=116.701±0.000nm^2 - Lower leaflet=115.560±0.000nm^2 - Upper leaflet=117.842±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 139.753 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=117.053±0.000nm^2 - Lower leaflet=117.348±0.000nm^2 - Upper leaflet=116.757±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 101.593 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.674±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.697±0.000nm^2
# Area: Membrane=114.569±0.000nm^2 - Lower leaflet=114.866±0.000nm^2 - Upper leaflet=114.272±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 101.935 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.715±0.000nm^2 - Lower leaflet=115.604±0.000nm^2 - Upper leaflet=115.826±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.433 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 138 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.702±0.000nm^2
# Area: Membrane=115.729±0.000nm^2 - Lower leaflet=116.286±0.000nm^2 - Upper leaflet=115.173±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 208.181 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.847±0.000nm^2 - Lower leaflet=116.217±0.000nm^2 - Upper leaflet=115.478±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.517 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 40 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.842±0.000nm^2 - Lower leaflet=115.870±0.000nm^2 - Upper leaflet=115.813±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 102.735 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 314 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.626±0.000nm^2 - Lower leaflet=115.446±0.000nm^2 - Upper leaflet=115.805±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 389.939 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.453±0.000nm^2 - Lower leaflet=116.332±0.000nm^2 - Upper leaflet=116.574±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.266 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.670±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=117.213±0.000nm^2 - Lower leaflet=117.915±0.000nm^2 - Upper leaflet=116.512±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 94.609 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 36 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.706±0.000nm^2 - Lower leaflet=0.682±0.000nm^2 - Upper leaflet=0.733±0.000nm^2
# Area: Membrane=120.067±0.000nm^2 - Lower leaflet=119.976±0.000nm^2 - Upper leaflet=120.158±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 109.778 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 32 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.731±0.000nm^2
# Area: Membrane=118.663±0.000nm^2 - Lower leaflet=117.376±0.000nm^2 - Upper leaflet=119.951±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.772 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.684±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=116.313±0.000nm^2 - Lower leaflet=116.755±0.000nm^2 - Upper leaflet=115.871±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 76.989 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=115.560±0.000nm^2 - Lower leaflet=115.235±0.000nm^2 - Upper leaflet=115.886±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.323 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.674±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.697±0.000nm^2
# Area: Membrane=114.536±0.000nm^2 - Lower leaflet=114.757±0.000nm^2 - Upper leaflet=114.314±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 104.729 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 37 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.668±0.000nm^2 - Lower leaflet=0.648±0.000nm^2 - Upper leaflet=0.691±0.000nm^2
# Area: Membrane=113.632±0.000nm^2 - Lower leaflet=114.018±0.000nm^2 - Upper leaflet=113.246±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.970 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 34 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=114.833±0.000nm^2 - Lower leaflet=114.356±0.000nm^2 - Upper leaflet=115.310±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 103.198 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.700±0.000nm^2
# Area: Membrane=115.327±0.000nm^2 - Lower leaflet=115.801±0.000nm^2 - Upper leaflet=114.853±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 94.366 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=115.606±0.000nm^2 - Lower leaflet=115.944±0.000nm^2 - Upper leaflet=115.269±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.744 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=117.362±0.000nm^2 - Lower leaflet=117.548±0.000nm^2 - Upper leaflet=117.177±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 95.042 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 166 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.677±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.044±0.000nm^2 - Lower leaflet=114.559±0.000nm^2 - Upper leaflet=115.528±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 233.376 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=116.622±0.000nm^2 - Lower leaflet=116.194±0.000nm^2 - Upper leaflet=117.050±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.048 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 36 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.648±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=115.356±0.000nm^2 - Lower leaflet=114.061±0.000nm^2 - Upper leaflet=116.651±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 118.672 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.417±0.000nm^2 - Lower leaflet=115.406±0.000nm^2 - Upper leaflet=115.428±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.762 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.723±0.000nm^2 - Lower leaflet=115.911±0.000nm^2 - Upper leaflet=115.535±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.795 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 136 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.719±0.000nm^2
# Area: Membrane=117.653±0.000nm^2 - Lower leaflet=117.440±0.000nm^2 - Upper leaflet=117.865±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 193.158 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 57 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=116.084±0.000nm^2 - Lower leaflet=116.445±0.000nm^2 - Upper leaflet=115.722±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 138.238 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.694±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.720±0.000nm^2
# Area: Membrane=117.907±0.000nm^2 - Lower leaflet=117.770±0.000nm^2 - Upper leaflet=118.045±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 102.921 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.664±0.000nm^2 - Upper leaflet=0.721±0.000nm^2
# Area: Membrane=117.587±0.000nm^2 - Lower leaflet=116.858±0.000nm^2 - Upper leaflet=118.315±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.588 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 33 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.418±0.000nm^2 - Lower leaflet=116.664±0.000nm^2 - Upper leaflet=116.173±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.038 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=115.760±0.000nm^2 - Lower leaflet=115.431±0.000nm^2 - Upper leaflet=116.089±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 107.006 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.664±0.000nm^2 - Upper leaflet=0.709±0.000nm^2
# Area: Membrane=116.537±0.000nm^2 - Lower leaflet=116.870±0.000nm^2 - Upper leaflet=116.204±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.867 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.096±0.000nm^2 - Lower leaflet=116.138±0.000nm^2 - Upper leaflet=116.054±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.961 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.790±0.000nm^2 - Lower leaflet=116.141±0.000nm^2 - Upper leaflet=115.440±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.407 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 73 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.720±0.000nm^2
# Area: Membrane=117.587±0.000nm^2 - Lower leaflet=117.163±0.000nm^2 - Upper leaflet=118.011±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 154.161 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 74 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.580±0.000nm^2 - Lower leaflet=115.632±0.000nm^2 - Upper leaflet=115.529±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 163.096 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.668±0.000nm^2 - Lower leaflet=0.646±0.000nm^2 - Upper leaflet=0.692±0.000nm^2
# Area: Membrane=113.592±0.000nm^2 - Lower leaflet=113.768±0.000nm^2 - Upper leaflet=113.415±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.640 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=114.801±0.000nm^2 - Lower leaflet=114.694±0.000nm^2 - Upper leaflet=114.908±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 94.513 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 138 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=116.547±0.000nm^2 - Lower leaflet=116.221±0.000nm^2 - Upper leaflet=116.873±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 236.880 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=117.356±0.000nm^2 - Lower leaflet=117.357±0.000nm^2 - Upper leaflet=117.356±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 103.937 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.567±0.000nm^2 - Lower leaflet=116.747±0.000nm^2 - Upper leaflet=116.388±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.726 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 66 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=116.782±0.000nm^2 - Lower leaflet=116.648±0.000nm^2 - Upper leaflet=116.915±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 168.125 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 39 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.709±0.000nm^2
# Area: Membrane=116.463±0.000nm^2 - Lower leaflet=116.631±0.000nm^2 - Upper leaflet=116.296±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 106.887 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 201 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.699±0.000nm^2
# Area: Membrane=115.412±0.000nm^2 - Lower leaflet=116.205±0.000nm^2 - Upper leaflet=114.619±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 282.105 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.732±0.000nm^2
# Area: Membrane=118.649±0.000nm^2 - Lower leaflet=117.281±0.000nm^2 - Upper leaflet=120.018±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.041 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.695±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.736±0.000nm^2
# Area: Membrane=118.233±0.000nm^2 - Lower leaflet=115.691±0.000nm^2 - Upper leaflet=120.776±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.935 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 104 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.705±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.744±0.000nm^2
# Area: Membrane=119.881±0.000nm^2 - Lower leaflet=117.677±0.000nm^2 - Upper leaflet=122.085±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 173.797 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 216 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=116.410±0.000nm^2 - Lower leaflet=115.857±0.000nm^2 - Upper leaflet=116.964±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 283.917 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 42 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.706±0.000nm^2 - Lower leaflet=115.574±0.000nm^2 - Upper leaflet=115.838±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 111.990 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 34 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.738±0.000nm^2
# Area: Membrane=118.742±0.000nm^2 - Lower leaflet=116.483±0.000nm^2 - Upper leaflet=121.002±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 111.402 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 16 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.714±0.000nm^2 - Lower leaflet=0.680±0.000nm^2 - Upper leaflet=0.750±0.000nm^2
# Area: Membrane=121.335±0.000nm^2 - Lower leaflet=119.734±0.000nm^2 - Upper leaflet=122.935±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 78.333 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 69 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.688±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.892±0.000nm^2 - Lower leaflet=117.295±0.000nm^2 - Upper leaflet=116.488±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 158.112 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.715±0.000nm^2
# Area: Membrane=116.859±0.000nm^2 - Lower leaflet=116.464±0.000nm^2 - Upper leaflet=117.253±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.269 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 105 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.695±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.728±0.000nm^2
# Area: Membrane=118.143±0.000nm^2 - Lower leaflet=116.961±0.000nm^2 - Upper leaflet=119.324±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 193.234 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.411±0.000nm^2 - Lower leaflet=115.435±0.000nm^2 - Upper leaflet=115.387±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.486 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.648±0.000nm^2 - Lower leaflet=116.739±0.000nm^2 - Upper leaflet=116.557±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.902 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.714±0.000nm^2 - Lower leaflet=115.947±0.000nm^2 - Upper leaflet=115.482±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 78.670 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.677±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=115.062±0.000nm^2 - Lower leaflet=115.128±0.000nm^2 - Upper leaflet=114.997±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.198 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 206 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.182±0.000nm^2 - Lower leaflet=115.982±0.000nm^2 - Upper leaflet=116.382±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 289.371 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 187 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=115.797±0.000nm^2 - Lower leaflet=115.083±0.000nm^2 - Upper leaflet=116.511±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 277.433 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 93 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.723±0.000nm^2
# Area: Membrane=117.347±0.000nm^2 - Lower leaflet=116.066±0.000nm^2 - Upper leaflet=118.629±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 161.275 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.695±0.000nm^2 - Lower leaflet=0.649±0.000nm^2 - Upper leaflet=0.744±0.000nm^2
# Area: Membrane=118.069±0.000nm^2 - Lower leaflet=114.201±0.000nm^2 - Upper leaflet=121.938±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 116.108 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 39 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.704±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.755±0.000nm^2
# Area: Membrane=119.745±0.000nm^2 - Lower leaflet=115.694±0.000nm^2 - Upper leaflet=123.796±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 106.678 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 129 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.649±0.000nm^2 - Upper leaflet=0.725±0.000nm^2
# Area: Membrane=116.553±0.000nm^2 - Lower leaflet=114.201±0.000nm^2 - Upper leaflet=118.904±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 204.450 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 38 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.648±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=114.728±0.000nm^2 - Lower leaflet=114.068±0.000nm^2 - Upper leaflet=115.388±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 108.553 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.674±0.000nm^2 - Lower leaflet=0.644±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=114.526±0.000nm^2 - Lower leaflet=113.403±0.000nm^2 - Upper leaflet=115.649±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.775 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 54 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.693±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.726±0.000nm^2
# Area: Membrane=117.803±0.000nm^2 - Lower leaflet=116.487±0.000nm^2 - Upper leaflet=119.119±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 128.929 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.714±0.000nm^2 - Lower leaflet=0.679±0.000nm^2 - Upper leaflet=0.752±0.000nm^2
# Area: Membrane=121.439±0.000nm^2 - Lower leaflet=119.483±0.000nm^2 - Upper leaflet=123.394±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.767 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.704±0.000nm^2 - Lower leaflet=0.682±0.000nm^2 - Upper leaflet=0.729±0.000nm^2
# Area: Membrane=119.745±0.000nm^2 - Lower leaflet=120.009±0.000nm^2 - Upper leaflet=119.482±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.851 ms (CPU)
# Goodbye!

# %%
u = mda.Universe('/mnt/ceph/users/mmofidi/gromacs/reduced/bound/N1/traj_continuous_v1_400_reduced.pdb', '/mnt/ceph/users/mmofidi/gromacs/reduced/bound/N1/traj_continuous_v1_400_reduced.xtc')
GRID = []
for ts in u.trajectory[-1000::10]:
    u.atoms.write('conf.gro')
    PROT = u.select_atoms("protein and name CA").positions[:,:2]
    os.system('fatslim apl -c conf.gro -n index.ndx --export-apl-raw bilayer_prot_apl.csv')
    plot_membrane_property_fromCSV(csv_filename="bilayer_prot_apl_frame_00000.csv", gro_filename="conf.gro", png_filename="./N1/" + str(ts.frame) + ".svg", protein=PROT/10.0)
    #grid = return_grid(csv_filename="bilayer_prot_apl_frame_00000.csv", gro_filename="conf.gro", resolution=50j)
    #GRID.append(grid)
    os.system('rm -rf *.old')
# Out:
# /mnt/home/asahoo/venv/lib/python3.8/site-packages/MDAnalysis/coordinates/XDR.py:203: UserWarning: Cannot write lock/offset file in same location as {self.filename}. Using slow offset calculation.
#   warnings.warn(f"Cannot write lock/offset file in same location as "
# /mnt/home/asahoo/venv/lib/python3.8/site-packages/MDAnalysis/coordinates/XDR.py:259: UserWarning: Couldn't save offsets because: [Errno 13] Permission denied: '/mnt/ceph/users/mmofidi/gromacs/reduced/bound/N1/.traj_continuous_v1_400_reduced.xtc_offsets.npz'
#   warnings.warn("Couldn't save offsets because: {}".format(e))
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 37 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.711±0.000nm^2 - Lower leaflet=116.980±0.000nm^2 - Upper leaflet=116.442±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 109.284 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 220 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=117.462±0.000nm^2 - Lower leaflet=117.452±0.000nm^2 - Upper leaflet=117.473±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 293.691 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 58 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.731±0.000nm^2
# Area: Membrane=118.661±0.000nm^2 - Lower leaflet=117.408±0.000nm^2 - Upper leaflet=119.914±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 128.970 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 42 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=117.109±0.000nm^2 - Lower leaflet=117.341±0.000nm^2 - Upper leaflet=116.876±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 104.866 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 138 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.718±0.000nm^2
# Area: Membrane=117.686±0.000nm^2 - Lower leaflet=117.563±0.000nm^2 - Upper leaflet=117.809±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 201.461 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 42 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=116.142±0.000nm^2 - Lower leaflet=115.523±0.000nm^2 - Upper leaflet=116.762±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 107.088 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 45 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.696±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.742±0.000nm^2
# Area: Membrane=118.306±0.000nm^2 - Lower leaflet=114.964±0.000nm^2 - Upper leaflet=121.649±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 118.354 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.719±0.000nm^2
# Area: Membrane=117.275±0.000nm^2 - Lower leaflet=116.626±0.000nm^2 - Upper leaflet=117.924±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.892 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=115.990±0.000nm^2 - Lower leaflet=115.487±0.000nm^2 - Upper leaflet=116.494±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.326 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 34 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.701±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.753±0.000nm^2
# Area: Membrane=119.111±0.000nm^2 - Lower leaflet=114.705±0.000nm^2 - Upper leaflet=123.518±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.886 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 30 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.694±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.732±0.000nm^2
# Area: Membrane=118.005±0.000nm^2 - Lower leaflet=115.914±0.000nm^2 - Upper leaflet=120.096±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 120.464 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.664±0.000nm^2 - Upper leaflet=0.722±0.000nm^2
# Area: Membrane=117.654±0.000nm^2 - Lower leaflet=116.837±0.000nm^2 - Upper leaflet=118.471±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.602 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 39 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=117.122±0.000nm^2 - Lower leaflet=117.125±0.000nm^2 - Upper leaflet=117.120±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 100.883 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 104 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.725±0.000nm^2
# Area: Membrane=117.113±0.000nm^2 - Lower leaflet=115.280±0.000nm^2 - Upper leaflet=118.946±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 192.520 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 37 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.684±0.000nm^2 - Lower leaflet=0.640±0.000nm^2 - Upper leaflet=0.732±0.000nm^2
# Area: Membrane=116.350±0.000nm^2 - Lower leaflet=112.695±0.000nm^2 - Upper leaflet=120.004±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 108.066 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 257 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.696±0.000nm^2
# Area: Membrane=114.676±0.000nm^2 - Lower leaflet=115.154±0.000nm^2 - Upper leaflet=114.198±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 327.176 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.699±0.000nm^2 - Lower leaflet=115.558±0.000nm^2 - Upper leaflet=115.839±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 106.648 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.688±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.907±0.000nm^2 - Lower leaflet=117.259±0.000nm^2 - Upper leaflet=116.555±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 102.127 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 83 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.804±0.000nm^2 - Lower leaflet=115.933±0.000nm^2 - Upper leaflet=115.676±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 147.823 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.684±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.351±0.000nm^2 - Lower leaflet=116.571±0.000nm^2 - Upper leaflet=116.131±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.080 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.800±0.000nm^2 - Lower leaflet=117.221±0.000nm^2 - Upper leaflet=116.379±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.738 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 100 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=117.423±0.000nm^2 - Lower leaflet=117.772±0.000nm^2 - Upper leaflet=117.074±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 197.185 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 33 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.696±0.000nm^2 - Lower leaflet=0.670±0.000nm^2 - Upper leaflet=0.724±0.000nm^2
# Area: Membrane=118.275±0.000nm^2 - Lower leaflet=117.880±0.000nm^2 - Upper leaflet=118.669±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 125.355 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.742±0.000nm^2
# Area: Membrane=118.954±0.000nm^2 - Lower leaflet=116.240±0.000nm^2 - Upper leaflet=121.667±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.040 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=115.784±0.000nm^2 - Lower leaflet=115.498±0.000nm^2 - Upper leaflet=116.070±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.047 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 179 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.700±0.000nm^2 - Lower leaflet=116.024±0.000nm^2 - Upper leaflet=115.375±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 257.436 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.677±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.055±0.000nm^2 - Lower leaflet=114.333±0.000nm^2 - Upper leaflet=115.778±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 107.289 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.709±0.000nm^2
# Area: Membrane=115.657±0.000nm^2 - Lower leaflet=115.084±0.000nm^2 - Upper leaflet=116.231±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 108.970 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=114.771±0.000nm^2 - Lower leaflet=114.593±0.000nm^2 - Upper leaflet=114.949±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.527 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.736±0.000nm^2
# Area: Membrane=119.013±0.000nm^2 - Lower leaflet=117.341±0.000nm^2 - Upper leaflet=120.686±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 107.404 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 30 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.699±0.000nm^2
# Area: Membrane=114.739±0.000nm^2 - Lower leaflet=114.915±0.000nm^2 - Upper leaflet=114.563±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.429 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 37 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.672±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.697±0.000nm^2
# Area: Membrane=114.317±0.000nm^2 - Lower leaflet=114.369±0.000nm^2 - Upper leaflet=114.264±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 109.668 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.663±0.000nm^2 - Lower leaflet=0.640±0.000nm^2 - Upper leaflet=0.687±0.000nm^2
# Area: Membrane=112.694±0.000nm^2 - Lower leaflet=112.682±0.000nm^2 - Upper leaflet=112.705±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.658 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 194 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.667±0.000nm^2 - Lower leaflet=0.646±0.000nm^2 - Upper leaflet=0.689±0.000nm^2
# Area: Membrane=113.375±0.000nm^2 - Lower leaflet=113.697±0.000nm^2 - Upper leaflet=113.052±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 258.794 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 113 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.676±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.700±0.000nm^2
# Area: Membrane=114.909±0.000nm^2 - Lower leaflet=115.035±0.000nm^2 - Upper leaflet=114.782±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 191.893 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 93 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=115.913±0.000nm^2 - Lower leaflet=115.719±0.000nm^2 - Upper leaflet=116.106±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 157.436 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 36 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=116.134±0.000nm^2 - Lower leaflet=114.864±0.000nm^2 - Upper leaflet=117.404±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 120.253 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.676±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=114.871±0.000nm^2 - Lower leaflet=114.857±0.000nm^2 - Upper leaflet=114.884±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.935 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.702±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.753±0.000nm^2
# Area: Membrane=119.315±0.000nm^2 - Lower leaflet=115.171±0.000nm^2 - Upper leaflet=123.460±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 79.465 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 30 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=116.872±0.000nm^2 - Lower leaflet=117.031±0.000nm^2 - Upper leaflet=116.713±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.267 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.671±0.000nm^2 - Upper leaflet=0.732±0.000nm^2
# Area: Membrane=119.073±0.000nm^2 - Lower leaflet=118.145±0.000nm^2 - Upper leaflet=120.001±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 94.536 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 72 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.703±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.743±0.000nm^2
# Area: Membrane=119.493±0.000nm^2 - Lower leaflet=117.085±0.000nm^2 - Upper leaflet=121.901±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 149.697 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 34 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.720±0.000nm^2
# Area: Membrane=117.431±0.000nm^2 - Lower leaflet=116.717±0.000nm^2 - Upper leaflet=118.145±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 100.246 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.538±0.000nm^2 - Lower leaflet=116.665±0.000nm^2 - Upper leaflet=116.411±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.411 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 40 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.694±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.720±0.000nm^2
# Area: Membrane=117.928±0.000nm^2 - Lower leaflet=117.704±0.000nm^2 - Upper leaflet=118.151±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.531 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 30 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.743±0.000nm^2
# Area: Membrane=119.033±0.000nm^2 - Lower leaflet=116.234±0.000nm^2 - Upper leaflet=121.832±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 100.165 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 34 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.676±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=114.997±0.000nm^2 - Lower leaflet=114.610±0.000nm^2 - Upper leaflet=115.384±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 114.319 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.719±0.000nm^2
# Area: Membrane=116.497±0.000nm^2 - Lower leaflet=115.105±0.000nm^2 - Upper leaflet=117.888±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.988 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.727±0.000nm^2
# Area: Membrane=117.495±0.000nm^2 - Lower leaflet=115.688±0.000nm^2 - Upper leaflet=119.302±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.499 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 260 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=116.756±0.000nm^2 - Lower leaflet=116.105±0.000nm^2 - Upper leaflet=117.406±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 323.443 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 62 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.671±0.000nm^2 - Lower leaflet=0.648±0.000nm^2 - Upper leaflet=0.696±0.000nm^2
# Area: Membrane=114.112±0.000nm^2 - Lower leaflet=114.099±0.000nm^2 - Upper leaflet=114.125±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 130.460 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 46 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=116.145±0.000nm^2 - Lower leaflet=116.336±0.000nm^2 - Upper leaflet=115.955±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 109.601 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=115.223±0.000nm^2 - Lower leaflet=114.530±0.000nm^2 - Upper leaflet=115.916±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.398 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=114.740±0.000nm^2 - Lower leaflet=114.541±0.000nm^2 - Upper leaflet=114.940±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 80.578 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.706±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.758±0.000nm^2
# Area: Membrane=120.087±0.000nm^2 - Lower leaflet=115.836±0.000nm^2 - Upper leaflet=124.338±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 95.023 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.697±0.000nm^2 - Lower leaflet=0.649±0.000nm^2 - Upper leaflet=0.748±0.000nm^2
# Area: Membrane=118.412±0.000nm^2 - Lower leaflet=114.176±0.000nm^2 - Upper leaflet=122.649±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 81.227 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.648±0.000nm^2 - Upper leaflet=0.720±0.000nm^2
# Area: Membrane=116.080±0.000nm^2 - Lower leaflet=114.018±0.000nm^2 - Upper leaflet=118.143±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.119 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 205 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.643±0.000nm^2 - Upper leaflet=0.715±0.000nm^2
# Area: Membrane=115.223±0.000nm^2 - Lower leaflet=113.139±0.000nm^2 - Upper leaflet=117.306±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 276.556 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.668±0.000nm^2 - Lower leaflet=0.647±0.000nm^2 - Upper leaflet=0.690±0.000nm^2
# Area: Membrane=113.490±0.000nm^2 - Lower leaflet=113.850±0.000nm^2 - Upper leaflet=113.131±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.262 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 343 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.672±0.000nm^2 - Lower leaflet=0.640±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=114.277±0.000nm^2 - Lower leaflet=112.668±0.000nm^2 - Upper leaflet=115.886±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 416.466 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 204 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.725±0.000nm^2
# Area: Membrane=117.122±0.000nm^2 - Lower leaflet=115.361±0.000nm^2 - Upper leaflet=118.884±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 283.524 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.707±0.000nm^2 - Lower leaflet=0.670±0.000nm^2 - Upper leaflet=0.748±0.000nm^2
# Area: Membrane=120.269±0.000nm^2 - Lower leaflet=117.867±0.000nm^2 - Upper leaflet=122.670±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 79.595 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.694±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.734±0.000nm^2
# Area: Membrane=117.988±0.000nm^2 - Lower leaflet=115.554±0.000nm^2 - Upper leaflet=120.422±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 102.650 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.701±0.000nm^2 - Lower leaflet=0.672±0.000nm^2 - Upper leaflet=0.732±0.000nm^2
# Area: Membrane=119.114±0.000nm^2 - Lower leaflet=118.189±0.000nm^2 - Upper leaflet=120.039±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 94.900 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.693±0.000nm^2 - Lower leaflet=0.672±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=117.859±0.000nm^2 - Lower leaflet=118.268±0.000nm^2 - Upper leaflet=117.450±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.565 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.712±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.768±0.000nm^2
# Area: Membrane=121.086±0.000nm^2 - Lower leaflet=116.220±0.000nm^2 - Upper leaflet=125.952±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 83.728 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.152±0.000nm^2 - Lower leaflet=116.179±0.000nm^2 - Upper leaflet=116.126±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.134 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.746±0.000nm^2
# Area: Membrane=118.744±0.000nm^2 - Lower leaflet=115.185±0.000nm^2 - Upper leaflet=122.303±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 83.335 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.705±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.751±0.000nm^2
# Area: Membrane=119.848±0.000nm^2 - Lower leaflet=116.512±0.000nm^2 - Upper leaflet=123.184±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 111.255 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.801±0.000nm^2 - Lower leaflet=115.811±0.000nm^2 - Upper leaflet=115.791±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.860 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 34 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.721±0.000nm^2
# Area: Membrane=117.236±0.000nm^2 - Lower leaflet=116.271±0.000nm^2 - Upper leaflet=118.201±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 102.228 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 39 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.709±0.000nm^2
# Area: Membrane=116.466±0.000nm^2 - Lower leaflet=116.591±0.000nm^2 - Upper leaflet=116.341±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 101.993 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.701±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.741±0.000nm^2
# Area: Membrane=119.150±0.000nm^2 - Lower leaflet=116.766±0.000nm^2 - Upper leaflet=121.535±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.164 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.112±0.000nm^2 - Lower leaflet=116.084±0.000nm^2 - Upper leaflet=116.141±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.015 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.742±0.000nm^2
# Area: Membrane=119.065±0.000nm^2 - Lower leaflet=116.483±0.000nm^2 - Upper leaflet=121.648±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 79.488 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.694±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.723±0.000nm^2
# Area: Membrane=117.900±0.000nm^2 - Lower leaflet=117.308±0.000nm^2 - Upper leaflet=118.491±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 106.851 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.719±0.000nm^2
# Area: Membrane=117.149±0.000nm^2 - Lower leaflet=116.409±0.000nm^2 - Upper leaflet=117.889±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.322 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.702±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.747±0.000nm^2
# Area: Membrane=119.384±0.000nm^2 - Lower leaflet=116.241±0.000nm^2 - Upper leaflet=122.526±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.796 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.695±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.725±0.000nm^2
# Area: Membrane=118.212±0.000nm^2 - Lower leaflet=117.541±0.000nm^2 - Upper leaflet=118.884±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.570 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 30 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.156±0.000nm^2 - Lower leaflet=116.194±0.000nm^2 - Upper leaflet=116.118±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.184 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 32 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.706±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.757±0.000nm^2
# Area: Membrane=119.935±0.000nm^2 - Lower leaflet=115.781±0.000nm^2 - Upper leaflet=124.090±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.524 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.702±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.749±0.000nm^2
# Area: Membrane=119.262±0.000nm^2 - Lower leaflet=115.661±0.000nm^2 - Upper leaflet=122.864±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 101.921 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.695±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.733±0.000nm^2
# Area: Membrane=118.170±0.000nm^2 - Lower leaflet=116.063±0.000nm^2 - Upper leaflet=120.278±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 93.225 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.664±0.000nm^2 - Upper leaflet=0.735±0.000nm^2
# Area: Membrane=118.693±0.000nm^2 - Lower leaflet=116.816±0.000nm^2 - Upper leaflet=120.571±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.571 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.167±0.000nm^2 - Lower leaflet=115.783±0.000nm^2 - Upper leaflet=116.550±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 107.999 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.695±0.000nm^2 - Lower leaflet=0.674±0.000nm^2 - Upper leaflet=0.718±0.000nm^2
# Area: Membrane=118.180±0.000nm^2 - Lower leaflet=118.569±0.000nm^2 - Upper leaflet=117.791±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.089 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.722±0.000nm^2
# Area: Membrane=117.687±0.000nm^2 - Lower leaflet=116.987±0.000nm^2 - Upper leaflet=118.387±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 83.795 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.679±0.000nm^2 - Upper leaflet=0.722±0.000nm^2
# Area: Membrane=118.942±0.000nm^2 - Lower leaflet=119.536±0.000nm^2 - Upper leaflet=118.347±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.664 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.697±0.000nm^2 - Lower leaflet=0.675±0.000nm^2 - Upper leaflet=0.721±0.000nm^2
# Area: Membrane=118.531±0.000nm^2 - Lower leaflet=118.834±0.000nm^2 - Upper leaflet=118.228±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.873 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=117.598±0.000nm^2 - Lower leaflet=117.751±0.000nm^2 - Upper leaflet=117.445±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 83.200 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 255 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.548±0.000nm^2 - Lower leaflet=116.628±0.000nm^2 - Upper leaflet=116.468±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 327.479 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=117.312±0.000nm^2 - Lower leaflet=117.229±0.000nm^2 - Upper leaflet=117.395±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 110.755 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=116.123±0.000nm^2 - Lower leaflet=116.427±0.000nm^2 - Upper leaflet=115.819±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.616 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 80 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.697±0.000nm^2 - Lower leaflet=0.673±0.000nm^2 - Upper leaflet=0.724±0.000nm^2
# Area: Membrane=118.558±0.000nm^2 - Lower leaflet=118.367±0.000nm^2 - Upper leaflet=118.750±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 157.901 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.688±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.897±0.000nm^2 - Lower leaflet=117.213±0.000nm^2 - Upper leaflet=116.580±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 94.476 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=115.700±0.000nm^2 - Lower leaflet=116.031±0.000nm^2 - Upper leaflet=115.369±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.576 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=117.356±0.000nm^2 - Lower leaflet=117.781±0.000nm^2 - Upper leaflet=116.931±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 79.220 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.700±0.000nm^2 - Lower leaflet=0.677±0.000nm^2 - Upper leaflet=0.725±0.000nm^2
# Area: Membrane=119.015±0.000nm^2 - Lower leaflet=119.197±0.000nm^2 - Upper leaflet=118.834±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.551 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.696±0.000nm^2 - Lower leaflet=0.672±0.000nm^2 - Upper leaflet=0.722±0.000nm^2
# Area: Membrane=118.296±0.000nm^2 - Lower leaflet=118.234±0.000nm^2 - Upper leaflet=118.358±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.937 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.703±0.000nm^2 - Lower leaflet=0.677±0.000nm^2 - Upper leaflet=0.730±0.000nm^2
# Area: Membrane=119.467±0.000nm^2 - Lower leaflet=119.213±0.000nm^2 - Upper leaflet=119.720±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 105.263 ms (CPU)
# Goodbye!

# %%
u = mda.Universe('/mnt/ceph/users/mmofidi/gromacs/reduced/bound/N2/traj_continuous_v1_400_reduced.pdb', '/mnt/ceph/users/mmofidi/gromacs/reduced/bound/N2/traj_continuous_v1_400_reduced.xtc')
GRID2 = []
for ts in u.trajectory[-1000::10]:
    u.atoms.write('conf.gro')
    PROT = u.select_atoms("protein and name CA").positions[:,:2]
    os.system('fatslim apl -c conf.gro -n index.ndx --export-apl-raw bilayer_prot_apl.csv')
    plot_membrane_property_fromCSV(csv_filename="bilayer_prot_apl_frame_00000.csv", gro_filename="conf.gro", png_filename="./N2/" + str(ts.frame) + ".png", protein=PROT/10.0)
    grid = return_grid(csv_filename="bilayer_prot_apl_frame_00000.csv", gro_filename="conf.gro", resolution=50j)
    GRID2.append(grid)
    os.system('rm -rf *.old')
# Out:
# /mnt/home/asahoo/venv/lib/python3.8/site-packages/MDAnalysis/coordinates/XDR.py:203: UserWarning: Cannot write lock/offset file in same location as {self.filename}. Using slow offset calculation.
#   warnings.warn(f"Cannot write lock/offset file in same location as "
# /mnt/home/asahoo/venv/lib/python3.8/site-packages/MDAnalysis/coordinates/XDR.py:259: UserWarning: Couldn't save offsets because: [Errno 13] Permission denied: '/mnt/ceph/users/mmofidi/gromacs/reduced/bound/N2/.traj_continuous_v1_400_reduced.xtc_offsets.npz'
#   warnings.warn("Couldn't save offsets because: {}".format(e))
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.700±0.000nm^2
# Area: Membrane=114.756±0.000nm^2 - Lower leaflet=114.773±0.000nm^2 - Upper leaflet=114.739±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.011 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.671±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.693±0.000nm^2
# Area: Membrane=114.122±0.000nm^2 - Lower leaflet=114.572±0.000nm^2 - Upper leaflet=113.671±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 95.607 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.672±0.000nm^2 - Lower leaflet=0.649±0.000nm^2 - Upper leaflet=0.696±0.000nm^2
# Area: Membrane=114.191±0.000nm^2 - Lower leaflet=114.224±0.000nm^2 - Upper leaflet=114.157±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.940 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.769±0.000nm^2 - Lower leaflet=115.941±0.000nm^2 - Upper leaflet=115.596±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 79.460 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.804±0.000nm^2 - Lower leaflet=115.994±0.000nm^2 - Upper leaflet=115.614±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 97.295 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.473±0.000nm^2 - Lower leaflet=116.408±0.000nm^2 - Upper leaflet=116.538±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.077 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.684±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.715±0.000nm^2
# Area: Membrane=116.344±0.000nm^2 - Lower leaflet=115.491±0.000nm^2 - Upper leaflet=117.197±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 78.002 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=115.289±0.000nm^2 - Lower leaflet=115.331±0.000nm^2 - Upper leaflet=115.247±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.613 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.672±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.695±0.000nm^2
# Area: Membrane=114.214±0.000nm^2 - Lower leaflet=114.458±0.000nm^2 - Upper leaflet=113.969±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.842 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.832±0.000nm^2 - Lower leaflet=115.866±0.000nm^2 - Upper leaflet=115.798±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.199 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.954±0.000nm^2 - Lower leaflet=116.093±0.000nm^2 - Upper leaflet=115.814±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.106 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=115.448±0.000nm^2 - Lower leaflet=115.938±0.000nm^2 - Upper leaflet=114.957±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.874 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.715±0.000nm^2
# Area: Membrane=117.538±0.000nm^2 - Lower leaflet=117.765±0.000nm^2 - Upper leaflet=117.310±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.860 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.702±0.000nm^2
# Area: Membrane=115.285±0.000nm^2 - Lower leaflet=115.368±0.000nm^2 - Upper leaflet=115.202±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.663 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 30 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.676±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.698±0.000nm^2
# Area: Membrane=114.904±0.000nm^2 - Lower leaflet=115.288±0.000nm^2 - Upper leaflet=114.520±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 111.105 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=116.045±0.000nm^2 - Lower leaflet=116.260±0.000nm^2 - Upper leaflet=115.830±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.190 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.684±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.232±0.000nm^2 - Lower leaflet=115.812±0.000nm^2 - Upper leaflet=116.651±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 90.120 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=117.288±0.000nm^2 - Lower leaflet=117.428±0.000nm^2 - Upper leaflet=117.147±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 76.927 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.702±0.000nm^2
# Area: Membrane=115.504±0.000nm^2 - Lower leaflet=115.918±0.000nm^2 - Upper leaflet=115.089±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 101.625 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.669±0.000nm^2 - Lower leaflet=0.648±0.000nm^2 - Upper leaflet=0.692±0.000nm^2
# Area: Membrane=113.749±0.000nm^2 - Lower leaflet=113.973±0.000nm^2 - Upper leaflet=113.526±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.585 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.684±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.710±0.000nm^2
# Area: Membrane=116.263±0.000nm^2 - Lower leaflet=116.094±0.000nm^2 - Upper leaflet=116.431±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.603 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=116.003±0.000nm^2 - Lower leaflet=116.044±0.000nm^2 - Upper leaflet=115.963±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.762 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=114.797±0.000nm^2 - Lower leaflet=114.703±0.000nm^2 - Upper leaflet=114.891±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.674 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 189 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.662±0.000nm^2 - Lower leaflet=0.640±0.000nm^2 - Upper leaflet=0.686±0.000nm^2
# Area: Membrane=112.595±0.000nm^2 - Lower leaflet=112.728±0.000nm^2 - Upper leaflet=112.462±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 256.430 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=115.454±0.000nm^2 - Lower leaflet=115.572±0.000nm^2 - Upper leaflet=115.336±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.550 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.668±0.000nm^2 - Lower leaflet=0.644±0.000nm^2 - Upper leaflet=0.694±0.000nm^2
# Area: Membrane=113.575±0.000nm^2 - Lower leaflet=113.353±0.000nm^2 - Upper leaflet=113.797±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.247 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 80 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.403±0.000nm^2 - Lower leaflet=115.384±0.000nm^2 - Upper leaflet=115.422±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 156.709 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.654±0.000nm^2 - Lower leaflet=115.642±0.000nm^2 - Upper leaflet=115.667±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 95.963 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.673±0.000nm^2 - Lower leaflet=0.652±0.000nm^2 - Upper leaflet=0.695±0.000nm^2
# Area: Membrane=114.357±0.000nm^2 - Lower leaflet=114.715±0.000nm^2 - Upper leaflet=113.999±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.110 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.344±0.000nm^2 - Lower leaflet=115.140±0.000nm^2 - Upper leaflet=115.548±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 98.871 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 29 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.673±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.697±0.000nm^2
# Area: Membrane=114.326±0.000nm^2 - Lower leaflet=114.383±0.000nm^2 - Upper leaflet=114.268±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.478 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=117.359±0.000nm^2 - Lower leaflet=117.766±0.000nm^2 - Upper leaflet=116.952±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.483 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=117.109±0.000nm^2 - Lower leaflet=117.417±0.000nm^2 - Upper leaflet=116.802±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 122.944 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 33 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=117.612±0.000nm^2 - Lower leaflet=117.827±0.000nm^2 - Upper leaflet=117.397±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 117.956 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.718±0.000nm^2
# Area: Membrane=117.619±0.000nm^2 - Lower leaflet=117.550±0.000nm^2 - Upper leaflet=117.688±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.468 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.717±0.000nm^2
# Area: Membrane=117.442±0.000nm^2 - Lower leaflet=117.233±0.000nm^2 - Upper leaflet=117.651±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 76.034 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.670±0.000nm^2 - Upper leaflet=0.715±0.000nm^2
# Area: Membrane=117.637±0.000nm^2 - Lower leaflet=117.936±0.000nm^2 - Upper leaflet=117.338±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 73.840 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=117.114±0.000nm^2 - Lower leaflet=117.541±0.000nm^2 - Upper leaflet=116.686±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 92.774 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=117.200±0.000nm^2 - Lower leaflet=117.660±0.000nm^2 - Upper leaflet=116.740±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 79.171 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=116.811±0.000nm^2 - Lower leaflet=117.723±0.000nm^2 - Upper leaflet=115.900±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.232 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 220 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.190±0.000nm^2 - Lower leaflet=116.307±0.000nm^2 - Upper leaflet=116.072±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 311.969 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 214 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.664±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.718±0.000nm^2 - Lower leaflet=116.835±0.000nm^2 - Upper leaflet=116.600±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 288.965 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 135 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.104±0.000nm^2 - Lower leaflet=116.109±0.000nm^2 - Upper leaflet=116.100±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 208.707 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 148 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.702±0.000nm^2
# Area: Membrane=115.315±0.000nm^2 - Lower leaflet=115.422±0.000nm^2 - Upper leaflet=115.209±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 218.966 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.427±0.000nm^2 - Lower leaflet=116.735±0.000nm^2 - Upper leaflet=116.119±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 76.697 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=117.252±0.000nm^2 - Lower leaflet=117.550±0.000nm^2 - Upper leaflet=116.954±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 76.977 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=115.361±0.000nm^2 - Lower leaflet=115.484±0.000nm^2 - Upper leaflet=115.238±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 124.199 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=116.525±0.000nm^2 - Lower leaflet=116.256±0.000nm^2 - Upper leaflet=116.795±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 72.664 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.694±0.000nm^2 - Lower leaflet=0.672±0.000nm^2 - Upper leaflet=0.718±0.000nm^2
# Area: Membrane=118.035±0.000nm^2 - Lower leaflet=118.308±0.000nm^2 - Upper leaflet=117.762±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.702 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.688±0.000nm^2 - Lower leaflet=0.666±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.927±0.000nm^2 - Lower leaflet=117.193±0.000nm^2 - Upper leaflet=116.661±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 78.297 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=117.393±0.000nm^2 - Lower leaflet=117.726±0.000nm^2 - Upper leaflet=117.060±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.083 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.381±0.000nm^2 - Lower leaflet=116.645±0.000nm^2 - Upper leaflet=116.118±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 73.293 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.715±0.000nm^2
# Area: Membrane=117.103±0.000nm^2 - Lower leaflet=117.002±0.000nm^2 - Upper leaflet=117.205±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 71.998 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.296±0.000nm^2 - Lower leaflet=115.179±0.000nm^2 - Upper leaflet=115.414±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.690 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.576±0.000nm^2 - Lower leaflet=115.436±0.000nm^2 - Upper leaflet=115.717±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 89.108 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.673±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.698±0.000nm^2
# Area: Membrane=114.411±0.000nm^2 - Lower leaflet=114.384±0.000nm^2 - Upper leaflet=114.438±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.858 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.662±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.616±0.000nm^2 - Lower leaflet=116.566±0.000nm^2 - Upper leaflet=116.667±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 101.770 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.760±0.000nm^2 - Lower leaflet=115.699±0.000nm^2 - Upper leaflet=115.821±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 71.237 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.707±0.000nm^2
# Area: Membrane=115.911±0.000nm^2 - Lower leaflet=115.864±0.000nm^2 - Upper leaflet=115.958±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 81.503 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.693±0.000nm^2 - Lower leaflet=0.670±0.000nm^2 - Upper leaflet=0.718±0.000nm^2
# Area: Membrane=117.816±0.000nm^2 - Lower leaflet=117.874±0.000nm^2 - Upper leaflet=117.757±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.239 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.002±0.000nm^2 - Lower leaflet=115.875±0.000nm^2 - Upper leaflet=116.129±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 113.046 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 16 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=115.939±0.000nm^2 - Lower leaflet=115.820±0.000nm^2 - Upper leaflet=116.058±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 73.901 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.715±0.000nm^2
# Area: Membrane=116.557±0.000nm^2 - Lower leaflet=115.858±0.000nm^2 - Upper leaflet=117.255±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 79.213 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.705±0.000nm^2
# Area: Membrane=115.538±0.000nm^2 - Lower leaflet=115.436±0.000nm^2 - Upper leaflet=115.639±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.819 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.669±0.000nm^2 - Lower leaflet=0.646±0.000nm^2 - Upper leaflet=0.694±0.000nm^2
# Area: Membrane=113.705±0.000nm^2 - Lower leaflet=113.616±0.000nm^2 - Upper leaflet=113.795±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 80.254 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.713±0.000nm^2
# Area: Membrane=116.742±0.000nm^2 - Lower leaflet=116.618±0.000nm^2 - Upper leaflet=116.866±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 80.896 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.693±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.719±0.000nm^2
# Area: Membrane=117.845±0.000nm^2 - Lower leaflet=117.739±0.000nm^2 - Upper leaflet=117.952±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.496 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.688±0.000nm^2 - Lower leaflet=0.669±0.000nm^2 - Upper leaflet=0.709±0.000nm^2
# Area: Membrane=117.043±0.000nm^2 - Lower leaflet=117.785±0.000nm^2 - Upper leaflet=116.301±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.773 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.674±0.000nm^2 - Upper leaflet=0.724±0.000nm^2
# Area: Membrane=118.691±0.000nm^2 - Lower leaflet=118.566±0.000nm^2 - Upper leaflet=118.817±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.169 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.720±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.777±0.000nm^2
# Area: Membrane=122.466±0.000nm^2 - Lower leaflet=117.584±0.000nm^2 - Upper leaflet=127.348±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.218 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.714±0.000nm^2
# Area: Membrane=116.444±0.000nm^2 - Lower leaflet=115.865±0.000nm^2 - Upper leaflet=117.022±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 78.599 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.676±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.699±0.000nm^2
# Area: Membrane=114.962±0.000nm^2 - Lower leaflet=115.328±0.000nm^2 - Upper leaflet=114.596±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.037 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.699±0.000nm^2 - Lower leaflet=0.672±0.000nm^2 - Upper leaflet=0.728±0.000nm^2
# Area: Membrane=118.799±0.000nm^2 - Lower leaflet=118.265±0.000nm^2 - Upper leaflet=119.333±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.854 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 31 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.664±0.000nm^2 - Upper leaflet=0.721±0.000nm^2
# Area: Membrane=117.535±0.000nm^2 - Lower leaflet=116.868±0.000nm^2 - Upper leaflet=118.202±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 110.420 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.695±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.727±0.000nm^2
# Area: Membrane=118.145±0.000nm^2 - Lower leaflet=117.011±0.000nm^2 - Upper leaflet=119.278±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.755 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.692±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.718±0.000nm^2
# Area: Membrane=117.673±0.000nm^2 - Lower leaflet=117.648±0.000nm^2 - Upper leaflet=117.699±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 85.558 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.678±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.697±0.000nm^2
# Area: Membrane=115.276±0.000nm^2 - Lower leaflet=116.211±0.000nm^2 - Upper leaflet=114.340±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.261 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.709±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.760±0.000nm^2
# Area: Membrane=120.527±0.000nm^2 - Lower leaflet=116.339±0.000nm^2 - Upper leaflet=124.715±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.832 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.708±0.000nm^2
# Area: Membrane=116.748±0.000nm^2 - Lower leaflet=117.317±0.000nm^2 - Upper leaflet=116.179±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 95.081 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.698±0.000nm^2 - Lower leaflet=0.673±0.000nm^2 - Upper leaflet=0.724±0.000nm^2
# Area: Membrane=118.603±0.000nm^2 - Lower leaflet=118.389±0.000nm^2 - Upper leaflet=118.818±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 87.816 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.699±0.000nm^2 - Lower leaflet=0.675±0.000nm^2 - Upper leaflet=0.724±0.000nm^2
# Area: Membrane=118.782±0.000nm^2 - Lower leaflet=118.839±0.000nm^2 - Upper leaflet=118.724±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 75.660 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 24 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.703±0.000nm^2 - Lower leaflet=0.678±0.000nm^2 - Upper leaflet=0.729±0.000nm^2
# Area: Membrane=119.458±0.000nm^2 - Lower leaflet=119.363±0.000nm^2 - Upper leaflet=119.553±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 99.657 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.689±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.712±0.000nm^2
# Area: Membrane=117.056±0.000nm^2 - Lower leaflet=117.391±0.000nm^2 - Upper leaflet=116.721±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 75.830 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 60 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.687±0.000nm^2 - Lower leaflet=0.665±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.838±0.000nm^2 - Lower leaflet=117.013±0.000nm^2 - Upper leaflet=116.663±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 160.150 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 23 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.699±0.000nm^2 - Lower leaflet=0.675±0.000nm^2 - Upper leaflet=0.724±0.000nm^2
# Area: Membrane=118.810±0.000nm^2 - Lower leaflet=118.810±0.000nm^2 - Upper leaflet=118.810±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.057 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.681±0.000nm^2 - Lower leaflet=0.659±0.000nm^2 - Upper leaflet=0.704±0.000nm^2
# Area: Membrane=115.782±0.000nm^2 - Lower leaflet=116.029±0.000nm^2 - Upper leaflet=115.536±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 103.010 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 22 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.658±0.000nm^2 - Upper leaflet=0.702±0.000nm^2
# Area: Membrane=115.525±0.000nm^2 - Lower leaflet=115.851±0.000nm^2 - Upper leaflet=115.200±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.482 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.683±0.000nm^2 - Lower leaflet=0.661±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=116.051±0.000nm^2 - Lower leaflet=116.256±0.000nm^2 - Upper leaflet=115.846±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 82.555 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.653±0.000nm^2 - Upper leaflet=0.700±0.000nm^2
# Area: Membrane=114.827±0.000nm^2 - Lower leaflet=114.920±0.000nm^2 - Upper leaflet=114.734±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 71.851 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 20 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.691±0.000nm^2 - Lower leaflet=0.667±0.000nm^2 - Upper leaflet=0.716±0.000nm^2
# Area: Membrane=117.391±0.000nm^2 - Lower leaflet=117.312±0.000nm^2 - Upper leaflet=117.470±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.039 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.680±0.000nm^2 - Lower leaflet=0.657±0.000nm^2 - Upper leaflet=0.706±0.000nm^2
# Area: Membrane=115.677±0.000nm^2 - Lower leaflet=115.635±0.000nm^2 - Upper leaflet=115.719±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.441 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 19 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.685±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.709±0.000nm^2
# Area: Membrane=116.481±0.000nm^2 - Lower leaflet=116.697±0.000nm^2 - Upper leaflet=116.266±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 76.710 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.686±0.000nm^2 - Lower leaflet=0.663±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=116.596±0.000nm^2 - Lower leaflet=116.620±0.000nm^2 - Upper leaflet=116.572±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 91.225 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 26 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.671±0.000nm^2 - Lower leaflet=0.651±0.000nm^2 - Upper leaflet=0.693±0.000nm^2
# Area: Membrane=114.094±0.000nm^2 - Lower leaflet=114.513±0.000nm^2 - Upper leaflet=113.674±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 88.633 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 18 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.676±0.000nm^2 - Lower leaflet=0.654±0.000nm^2 - Upper leaflet=0.700±0.000nm^2
# Area: Membrane=114.964±0.000nm^2 - Lower leaflet=115.060±0.000nm^2 - Upper leaflet=114.868±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 78.779 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 25 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.682±0.000nm^2 - Lower leaflet=0.655±0.000nm^2 - Upper leaflet=0.711±0.000nm^2
# Area: Membrane=115.978±0.000nm^2 - Lower leaflet=115.334±0.000nm^2 - Upper leaflet=116.622±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 86.164 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 17 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.679±0.000nm^2 - Lower leaflet=0.656±0.000nm^2 - Upper leaflet=0.703±0.000nm^2
# Area: Membrane=115.395±0.000nm^2 - Lower leaflet=115.522±0.000nm^2 - Upper leaflet=115.268±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 77.218 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 28 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.703±0.000nm^2 - Lower leaflet=0.668±0.000nm^2 - Upper leaflet=0.740±0.000nm^2
# Area: Membrane=119.467±0.000nm^2 - Lower leaflet=117.525±0.000nm^2 - Upper leaflet=121.409±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.957 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 27 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.675±0.000nm^2 - Lower leaflet=0.650±0.000nm^2 - Upper leaflet=0.701±0.000nm^2
# Area: Membrane=114.703±0.000nm^2 - Lower leaflet=114.417±0.000nm^2 - Upper leaflet=114.990±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 84.212 ms (CPU)
# Goodbye!
# FATSLiM - Fast Analysis Toolbox for Simulations of Lipid Membranes
# version 0.2.2
# Copyright (c) 2013-2016 Sébastien Buchoux
#
# Running command: 'apl'... This may take some time, be patient!
# Analysis will be performed using 32 threads.
# Analysing frame     1/    1 (time: 0 ps)... done in 21 ms (Remaining: 0 s)
# Results:
# Average values over 1 processed frames:
# Area per lipid: Membrane=0.690±0.000nm^2 - Lower leaflet=0.660±0.000nm^2 - Upper leaflet=0.722±0.000nm^2
# Area: Membrane=117.330±0.000nm^2 - Lower leaflet=116.244±0.000nm^2 - Upper leaflet=118.416±0.000nm^2
#
# DEBUG!
# 'apl' command executed in 96.325 ms (CPU)
# Goodbye!

# %%
GRID = np.array(GRID)

# %%
replicated_positions, box = replicate_xy('conf.gro', n_replicas=1)

# %%
compute_apl_voronoi(replicated_positions, plot=False)
# Out:
# array([0.29821737, 0.40246787, 0.33013476, ..., 0.31855077, 0.40329385,
#        0.27634355])

# %%
len(replicated_positions)/9
# Out:
# 340.0

# %%
box
# Out:
# array([107.6791, 107.6791, 136.8677], dtype=float32)

# %%
-1 -1
-1 0
-1 1
0 -1
0 0
