# %%
import matplotlib.pyplot as plt
import numpy as np

# Load data (assuming two columns: residue number, helix angle)
data = np.loadtxt("bendix2_N2_3920.dat")
residue = data[:, 0]
angle1 = data[:, 1]
angle2 = data[:, 2]

plt.figure(figsize=(8, 5), dpi=300)
plt.plot(residue, angle1, linewidth=2, color='darkblue')
plt.plot(residue, angle2, linewidth=2, color='darkred')

plt.xlabel("Residue", fontsize=14)
plt.ylabel("Helix Angle (°)", fontsize=14)
#plt.title("Helix Angle Along the Helix", fontsize=16)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.grid(True)
plt.xlim(1,34)
plt.ylim(0,90)

plt.tight_layout()
plt.savefig("helix_angle_plot_N3_3920.png", dpi=600)
plt.show()

# %%
def angle_to_radius(angle_deg, arc_length=7.2):  # 3.8 Å ≈ Cα–Cα distance
    angle_rad = np.radians(angle_deg)
    return arc_length / angle_rad

radius = angle_to_radius(angle)

fig, ax1 = plt.subplots(figsize=(8, 5), dpi=300)

color = 'tab:blue'
ax1.set_xlabel("Residue", fontsize=14)
ax1.set_ylabel("Helix Angle (°)", color=color, fontsize=14)
ax1.plot(residue, angle, color=color, linewidth=2)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel("Radius of Curvature (Å)", color=color, fontsize=14)
ax2.plot(residue, radius, color=color, linestyle='--')
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Helix Angle and Radius of Curvature", fontsize=16)
fig.tight_layout()
plt.savefig("helix_angle_and_radius_3_3478.png", dpi=600)
plt.show()
# Out:
# /var/folders/r5/n8brp0qx0lgcbks1dqy53p000000gp/T/ipykernel_53473/1825745433.py:3: RuntimeWarning: divide by zero encountered in divide
#   return arc_length / angle_rad
